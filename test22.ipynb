# %% [markdown]
# ### Imports and constants

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
import numpy as np
import dataframe_image as dfi

# %%
EPW=pd.read_csv("EquipParamWeapon.csv").dropna(subset="Name").replace("Great epee","Great Épée",regex=True)
RPW=pd.read_csv("ReinforceParamWeapon.csv")
CCG=pd.read_csv("CalcCorrectGraph.csv")
AECP=pd.read_csv("AttackElementCorrectParam.csv")
PAA=pd.read_csv("Physical AtkAttribute.csv").dropna(subset="Weapon").replace("Miséricorde","Misericorde").replace("Varré's Bouquet","Varre's Bouquet")
RD=pd.read_csv("Raw_Data.csv").replace("Great Epee","Great Épée")

# %%
dmgTypes=["Standard","Strike","Slash","Pierce","Magic","Fire","Lightning","Holy"]
baseInfusions=["Heavy","Fire","Keen","Lightning","Magic","Cold","Sacred","FLame Art","Blood","Occult"]
infusionOrder=["Heavy","Hvy+Gse","Fire","Fire+FS","Keen","Keen+Gse","Lightning","Magic","Cold","Sacred","Sacred+SB","Flame Art","Flame Art+FS","Blood","Poison","Occult","Standard","Std+Gse"]

# %%
weaponClass={
    29: "Halberds",
    25: "Spears",
    3: "Straight Swords",
    1: "Daggers",
    9: "Curved Swords",
    5: "Greatswords",
    7: "Colossal Swords",
    15: "Thrusting Swords",
    16: "Heavy Thrusting Swords",
    11: "Curved Greatswords",
    13: "Katanas",
    14: "Twinblades",
    21: "Hammers",
    23: "Greathammers",
    24: "Flails",
    17: "Axes",
    19: "Greataxes",
    28: "Great Spears",
    31: "Scythes",
    39: "Whips",
    35: "Fists",
    37: "Claws",
    41: "Colossal Weapons",
}
wepClass={
    29: "Hal",
    25: "Spr",
    3: "SS",
    1: "Dag",
    9: "CS",
    5: "GS",
    7: "UGS",
    15: "TS",
    16: "HTS",
    11: "CGS",
    13: "Kat",
    14: "Tb",
    21: "Ham",
    23: "GH",
    24: "Flails",
    17: "Axes",
    19: "GA",
    28: "GSpr",
    31: "Scythes",
    39: "Whips",
    35: "Fists",
    37: "Claws",
    41: "CW",
}

# %% [markdown]
# ### Functions

# %%
def ARcalculator(weapon:str,infusion:str,build:list[int],twoH:bool=False,reinforcmentLvl:any="max")->np.ndarray:
    """
    Calculates weapon AR
    Parameters:
        weapon: string
            Weapon name.
        infusion: string
            Infusion name. For standard use "".
        build: list of length 5
            STR, DEX, INT, FTH, ARC.
        twoH: boolean
            Is the weapon two handed?
        reinforcmentLvl: int or "max"
            Weapon reinforcment level.
    Output:
        numpy array of length 8
    """
    infusionOffset={
        "":0,
        "Heavy":100,
        "Keen":200,
        "Quality":300, # lmao
        "Fire":400,
        "Flame Art":500,
        "Lightning":600,
        "Sacred":700,
        "Magic":800,
        "Cold":900,
        "Poison":1000,
        "Blood":1100,
        "Occult":1200,
    }
    def CalcCorrectFormula(stat,ccgData):
        # used for stat scaling calculations
        for i in range(5):
            if ccgData.iloc[0,2+i]>stat:
                break
        statMin=ccgData.iloc[0,2+i-1]
        statMax=ccgData.iloc[0,2+i]
        ratio=(stat-statMin)/(statMax-statMin)
        expMin=ccgData.iloc[0,12+i-1]
        growth=ratio**expMin if expMin>0 else 1-(1-ratio)**abs(expMin)
        growthMin=ccgData.iloc[0,7+i-1]
        growthMax=ccgData.iloc[0,7+i]
        return (growthMin+(growthMax-growthMin)*growth)/100
    if "2H" in weapon:
        weapon=weapon.replace("2H ","")
        twoH=True
    if reinforcmentLvl=="max" or reinforcmentLvl>10:
        if reinforcmentLvl=="max": reinforcmentLvl=25
        reinforcmentLvl=min(reinforcmentLvl,RD[RD["Name"]==weapon]["Max Upgrade"].values[0])
    ID=EPW[EPW["Name"]==weapon]["ID"].values[0]+infusionOffset[infusion]
    rtID=EPW[EPW["ID"]==ID]["reinforceTypeId"].values[0]
    ccgID=EPW[EPW["ID"]==ID][["correctType_Physics","correctType_Magic","correctType_Fire","correctType_Thunder","correctType_Dark"]].values[0]
    aecID=EPW[EPW["ID"]==ID]["attackElementCorrectId"].values[0]
    baseDmg=EPW[EPW["ID"]==ID][["attackBasePhysics","attackBaseMagic","attackBaseFire","attackBaseThunder","attackBaseDark"]].to_numpy()[0]
    baseScaling=EPW[EPW["ID"]==ID][["correctStrength","correctAgility","correctMagic","correctFaith","correctLuck"]].to_numpy()[0]/100
    baseDmgReinforcment=RPW[RPW["ID"]==rtID+reinforcmentLvl][["Physical Attack","Magic Attack","Fire Attack","Lightning Attack","Holy Attack"]].to_numpy()[0]
    baseScalingReinforcment=RPW[RPW["ID"]==rtID+reinforcmentLvl][["Str Scaling","Dex Scaling","Int Scaling","Fai Scaling","Arc Scaling"]].to_numpy()[0]
    dmg=baseDmg*baseDmgReinforcment # element
    scaling=baseScaling*baseScalingReinforcment # stat
    tmp=baseDmg*baseDmgReinforcment
    for i in range(5): #element
        if dmg[i]:
            for j in range(5): #stat
                if AECP[AECP["Row ID"]==aecID].iloc[0,1+5*i+j]:
                    stat=build[j] if (j!=0 or not twoH) else int(build[j]*1.5)
                    tmp[i]+=dmg[i]*scaling[j]*CalcCorrectFormula(stat,CCG[CCG["ID"]==ccgID[i]])
    # convert 5-array into 8-array
    physType={"Standard":0,"Strike":1,"Slash":2,"Pierce":3}[PAA[PAA["Weapon"]==weapon]["1h R1 1"].values[0]]
    res=np.concatenate([[0,0,0,0],tmp[1:]])
    res[physType]=tmp[0]
    return(res)

# %%
def ARtoDMG(AR:list[int],DEF:list[int]=[140,140,140,140,155,187,127,155],ABS:list[int]=[0.32,0.30,0.35,0.35,0.25,0.28,0.25,0.26])->np.ndarray:
    """
    Converts an AR array to a real damage array
    Parameters:
        AR: list of length 8
            AR for each damage type.
        DEF: list of length 8
            Defenses for each damage type. Default values found in earlier section.
        ABS: list of length 8
            Absorbtions for each damage type. Default values found in earlier section.
    Output:
        numpy array of length 8
    """
    res=[]
    for x,y,z in zip(AR,DEF,ABS):
        if y>x*8:
            res.append((1-z)*0.1*x) 
        elif y>x:
            res.append((1-z)*(19.2/49*(x/y-0.125)**2+0.1)*x)
        elif y>x*0.4:
            res.append((1-z)*(-0.4/3*(x/y-2.5)**2+0.7)*x)
        elif y>x/8:
            res.append((1-z)*(-0.8/121*(x/y-8)**2+0.9)*x)
        else:
            res.append((1-z)*0.9*x)
    return np.array(res)

# %%
def DMGtable(weapons:list[str],builds:dict[str,list[int]],infusions:dict[str,list[int]],weaponBuffs:bool=True,counterHits:bool=True)->pd.DataFrame:
    """
    Computes damage for each weapon/infusion/build combination.
    Parameters:
        weapons: list of string
            List of weapon names.
        builds: dict {string:list of int of length 5}
            Dict of builds with the keys being build name and values being STR DEX INT FTH ARC.
        infusions: dict {string:list of strings}
            Dict to specify what infusions we want for each build. Keys are build names and values are list of infusions.
        weaponBuffs: boolean
            Display weapon buffs like greases or Flaming Strike/Sacred Blade.
        counterHits: boolean
            Display counter hit damage and spear tali counter hit damage
    """
    buffs={
        "Heavy":["Hvy+Gse",np.array([0,0,0,0,0,0,110,0])],
        "Fire":["Fire+FS",np.array([0,0,0,0,0,90,0,0])],
        "Keen":["Keen+Gse",np.array([0,0,0,0,0,0,110,0])],
        "Sacred":["Sacred+SB",np.array([0,0,0,0,0,0,0,90])],
        "Flame Art":["Flame Art+FS",np.array([0,0,0,0,0,90,0,0])],
        # buffable split dmg weapons
        "Treespear":np.array([0,0,0,0,0,0,0,110]),
        "Great Club":np.array([0,0,0,0,0,110,0,0]),
        "Troll's Hammer":np.array([0,0,0,0,0,110,0,0]),
        "Clayman's Harpoon":np.array([0,0,0,0,110,0,0,0]),
    }
    res=[]
    for weapon in weapons:
        if EPW[EPW["Name"]==weapon.replace("2H ","")].empty:
            print(f"Weapon does not exist: {weapon}")
            continue
        columns=[]
        normal,prc,spr=[],[],[]
        for build in builds:
            # somber weapons
            if RD[RD["Name"]==weapon.replace("2H ","")]["Infusable"].values[0]=="No":
                dmg=ARtoDMG(ARcalculator(weapon,"",builds[build]))
                normal.append(dmg.sum())
                if counterHits and dmg[3]:
                    prc.append((dmg*np.array([1,1,1,1.15,1,1,1,1])).sum())
                    spr.append((dmg*np.array([1,1,1,1.15*1.15,1,1,1,1])).sum())
                columns.append((f"{build} • {' '.join(map(str,builds[build]))}","Standard"))
                # if buffable (bhf, bouquet, ripple*2, treespear, great club, troll's hammer)
                if weaponBuffs and EPW[EPW["Name"]==weapon.replace("2H ","")]["isEnhance"].values[0]==1:
                    grease=buffs[weapon] if weapon in buffs else np.array([0,0,0,0,0,0,110,0])
                    dmg=ARtoDMG(ARcalculator(weapon,"",builds[build])+grease)
                    normal.append(dmg.sum())
                    if counterHits and dmg[3]:
                        prc.append((dmg*np.array([1,1,1,1.15,1,1,1,1])).sum())
                        spr.append((dmg*np.array([1,1,1,1.15*1.15,1,1,1,1])).sum())
                    columns.append((f"{build} • {' '.join(map(str,builds[build]))}","Std+Gse"))
            # infusable weapons
            else:
                for infusion in infusions[build]:
                    dmg=ARtoDMG(ARcalculator(weapon,infusion,builds[build]))
                    normal.append(dmg.sum())
                    if counterHits and dmg[3]:
                        prc.append((dmg*np.array([1,1,1,1.15,1,1,1,1])).sum())
                        spr.append((dmg*np.array([1,1,1,1.15*1.15,1,1,1,1])).sum())
                    columns.append((f"{build} • {' '.join(map(str,builds[build]))}",infusion))
                    # compute buffs (grease, flaming strike etc)
                    if weaponBuffs and infusion in buffs:
                        grease=buffs[weapon] if weapon in buffs else buffs[infusion][1]
                        dmg=ARtoDMG(ARcalculator(weapon,infusion,builds[build])+grease)
                        normal.append(dmg.sum())
                        if counterHits and dmg[3]:
                            prc.append((dmg*np.array([1,1,1,1.15,1,1,1,1])).sum())
                            spr.append((dmg*np.array([1,1,1,1.15*1.15,1,1,1,1])).sum())
                        columns.append((f"{build} • {' '.join(map(str,builds[build]))}",buffs[infusion][0]))
        res.append(pd.DataFrame([normal,prc,spr],index=pd.MultiIndex.from_tuples([(weapon,"No Prc"),(weapon,"Prc+15%"),(weapon,"Prc+32%")]),columns=pd.MultiIndex.from_tuples(columns)))
    res=pd.concat(res).dropna(how="all")
    # reorder columns to respect infusion order
    res=res.sort_index(axis=1,level=1,sort_remaining=False,key=lambda x:x.map({a:i for i,a in enumerate(infusionOrder)}))
    res=res.sort_index(axis=1,level=0,sort_remaining=False,key=lambda x:x.map({a:i for i,a in enumerate(res.columns.get_level_values(0).unique())}))
    # add weapon class to index
    res.index=pd.MultiIndex.from_tuples([(f"{'2H ' if '2H' in w else ''}{weaponClass[EPW[EPW['Name']==w.replace('2H ','')]['wepType'].values[0]]}",w,d) for w,d in res.index])
    # put weapons of the same class next to each other (doesnt work)
    #res=res.sort_index(level=[0,1],key=lambda x:x.map({w:EPW[EPW["Name"]==w.replace("2H ","")]["wepType"].values[0] for w in res.index.get_level_values(0).unique()}))
    return res

# %%
def fancyTable(DMGtable:pd.DataFrame,comparison:str="row",displayPercentage:bool=True,showStats:bool=True,multicolor:bool=True,showWeaponClass:bool=True,wideDisplay:bool=False,saveOutput:bool=False)->None:
    """
    Displays a fancy damage table.
    Parameters:
        DMGtable: MultiIndexed pandas DataFrame
            Columns are build>infusion. Rows are weapon name>pierce bonus
        comparison: "row", "class", "all"
            Compute the difference ratio between cell damage and max row/weapon class/all damage.
        displayPercentage: boolean
            Display percentage value in cell.
        showStats: boolean
            Display build stat spread in column header.
        multicolor: boolean
            Display one color per build.
        showWeaponClass: boolean
            Display weapon class.
        wideDisplay: boolean
            Display a scrollable table instead of wider cells.
        saveOutput: boolean
            Save output as png.
    """
    tmp=DMGtable.apply(np.floor).astype("Int64")
    # sort by damage
    classes=tmp.index.get_level_values(0).unique() # we want to keep weapon class order most likely
    orderDesc=tmp.loc[pd.IndexSlice[:,:,"No Prc"],:].max(axis=1).sort_values(ascending=False).index.get_level_values(1)
    tmp=tmp.sort_index(level=1,key=lambda x:x.map({ii:i for i,ii in enumerate(orderDesc)}))
    if comparison!="all":
        tmp=tmp.sort_index(level=0,sort_remaining=False,key=lambda x:x.map({ii:i for i,ii in enumerate(classes)})) # restore class order
    # percentages
    if comparison=="row":
        DMGratio=tmp.apply(lambda x:x/x.max()*100-100,axis=1).astype(float)
    if comparison=="class":
        DMGratio=tmp.apply(lambda x:x/tmp.loc[pd.IndexSlice[x.name[0],:,x.name[2]],:].max().max()*100-100,axis=1).astype(float)
    elif comparison=="all":
        DMGratio=tmp.apply(lambda x:x/tmp.max().max()*100-100,axis=1).astype(float)
    res=tmp.copy()
    for c in tmp.columns:
        if displayPercentage:
            res[c]=res[c].map(lambda x:str(x).replace("<NA>","-"))+" ("+DMGratio[c].round(1).map(lambda x:("👑" if x==0 else (("+" if x>=0 else "-")+str(abs(x)).replace("nan",""))+"%"))+")"
        else:
            res[c]=res[c].map(lambda x:str(x).replace("<NA>","-"))
    # display max of each row in bold
    res=res.style.format(precision=1).apply(lambda x:tmp.apply(lambda x:x.apply(lambda xx:'font-weight: bold' if not pd.isna(xx) and xx==x.max() else ''),axis=1),axis=None) # miracle
    # background color
    for i in tmp.index:
        vmin=-20
        if not multicolor:
            res.background_gradient(cmap="Greens",axis=None,gmap=DMGratio.fillna(vmin),vmin=vmin,vmax=0)
        else:
            cmaps=[["white","red"],["white","gold"],["white","blue"],["white","orange"],["white","violet"]]
            for j,jj in enumerate(tmp.columns.get_level_values(0).unique()):
                res.background_gradient(cmap=LinearSegmentedColormap.from_list("",cmaps[j%5]),axis=None,gmap=DMGratio.fillna(vmin),subset=(i,tmp[[jj]].columns),vmin=vmin,vmax=2)
    # weapon class display and hide pierce bonus if useless
    hide=[]
    if not showWeaponClass:
        hide.append(0)
    if tmp.index.get_level_values(2).drop_duplicates().size==1:
        hide.append(2)
    res=res.hide(level=hide)
    # borders
    for i in [j for i,j in zip(tmp.columns[:-1],tmp.columns[1:]) if i[0]!=j[0]]:
        res.set_table_styles({i: [{'selector': '', 'props': 'border-left: 1px solid grey !important;'}]}, overwrite=False)
    if res.index.nlevels>1:
        for i in [j for i,j in zip(tmp.index[:-1],tmp.index[1:]) if i[0]!=j[0]]:
            res.set_table_styles({i: [{'selector': '', 'props': 'border-top: 1px solid grey !important;'}]}, overwrite=False, axis=1)
    # stats
    if not showStats:
        res.format_index(lambda x:x.split("•")[0].rstrip(),axis=1)
    # vs code display
    if wideDisplay:
        from IPython.display import HTML
        display(HTML(f"<div style='width: 2500px'>{res.to_html()}</div>"))
    else:
        display(res)
    # saving output as image
    if saveOutput: dfi.export(res,"DMGtable.png")

# %%
def weaponsOfClass(wClass:str)->list[str]:
    # returns a list of all weappons of the specified class
    classes={v:k for k,v in weaponClass.items()}|{v:k for k,v in wepClass.items()}
    tmp=EPW[EPW["wepType"]==classes[wClass.replace("2H ","")]]
    return [f"2H {w}" if "2H" in wClass else w for w in tmp[tmp["reinforceTypeId"].isin([0,2200])]["Name"]]

# %% [markdown]
# ### Output

# %% [markdown]
# Usual weapons on the five main builds (infusable and somber in two different tables)

# %%
weapons=["Dismounter","Banished Knight's Halberd","2H Cleanrot Knight's Sword","Cleanrot Knight's Sword","Wakizashi","Erdsteel Dagger","Lance","Partisan","Spiked Spear","2H Shamshir","2H Godskin Stitcher"]
builds={"STR":[66,16,9,9,7],"DEX":[16,66,9,9,7],"INT":[21,20,50,9,7],"FTH":[21,20,9,50,7],"ARC":[24,19,7,8,50]}
infusions={"STR":["Heavy","Fire"],"DEX":["Keen","Lightning"],"INT":["Magic","Cold"],"FTH":["Sacred"],"ARC":["Occult","Blood"]}
fancyTable(DMGtable(weapons,builds,infusions,weaponBuffs=True,counterHits=True),comparison="class",displayPercentage=True,showStats=True,multicolor=True,showWeaponClass=True)
weapons=["Bloodhound's Fang","Morgott's Cursed Sword","Cinquedea","Scorpion's Stinger","Reduvia","Carian Knight's Sword","Coded Sword","Treespear"]
infusions={"STR":[],"DEX":[],"INT":[],"FTH":[],"ARC":[]}
fancyTable(DMGtable(weapons,builds,infusions,weaponBuffs=True,counterHits=True),comparison="class",displayPercentage=True,showStats=True,multicolor=True,showWeaponClass=True)
# Out:
# <style type="text/css">
# #T_f544c .col4 {
#   border-left: 1px solid grey !important;
# }
# #T_f544c .col7 {
#   border-left: 1px solid grey !important;
# }
# #T_f544c .col9 {
#   border-left: 1px solid grey !important;
# }
# #T_f544c .col11 {
#   border-left: 1px solid grey !important;
# }
# #T_f544c .row1 {
#   border-top: 1px solid grey !important;
# }
# #T_f544c .row4 {
#   border-top: 1px solid grey !important;
# }
# #T_f544c .row7 {
#   border-top: 1px solid grey !important;
# }
# #T_f544c .row10 {
#   border-top: 1px solid grey !important;
# }
# #T_f544c .row12 {
#   border-top: 1px solid grey !important;
# }
# #T_f544c .row15 {
#   border-top: 1px solid grey !important;
# }
# #T_f544c .row21 {
#   border-top: 1px solid grey !important;
# }
# #T_f544c .row22 {
#   border-top: 1px solid grey !important;
# }
# #T_f544c_row0_col0, #T_f544c_row0_col2, #T_f544c_row0_col4, #T_f544c_row0_col8, #T_f544c_row0_col11, #T_f544c_row0_col12, #T_f544c_row1_col0, #T_f544c_row1_col2, #T_f544c_row1_col4, #T_f544c_row1_col8, #T_f544c_row1_col11, #T_f544c_row1_col12, #T_f544c_row2_col2, #T_f544c_row2_col8, #T_f544c_row2_col11, #T_f544c_row2_col12, #T_f544c_row3_col8, #T_f544c_row3_col11, #T_f544c_row4_col2, #T_f544c_row4_col4, #T_f544c_row4_col5, #T_f544c_row4_col8, #T_f544c_row4_col11, #T_f544c_row4_col12, #T_f544c_row5_col2, #T_f544c_row5_col4, #T_f544c_row5_col8, #T_f544c_row5_col11, #T_f544c_row5_col12, #T_f544c_row6_col2, #T_f544c_row6_col4, #T_f544c_row6_col6, #T_f544c_row6_col7, #T_f544c_row6_col8, #T_f544c_row6_col9, #T_f544c_row6_col11, #T_f544c_row6_col12, #T_f544c_row7_col0, #T_f544c_row7_col2, #T_f544c_row7_col4, #T_f544c_row7_col5, #T_f544c_row7_col8, #T_f544c_row7_col11, #T_f544c_row7_col12, #T_f544c_row8_col2, #T_f544c_row8_col4, #T_f544c_row8_col8, #T_f544c_row8_col11, #T_f544c_row8_col12, #T_f544c_row9_col2, #T_f544c_row9_col8, #T_f544c_row9_col11, #T_f544c_row10_col0, #T_f544c_row10_col1, #T_f544c_row10_col2, #T_f544c_row10_col3, #T_f544c_row10_col4, #T_f544c_row10_col5, #T_f544c_row10_col6, #T_f544c_row10_col7, #T_f544c_row10_col8, #T_f544c_row10_col9, #T_f544c_row10_col11, #T_f544c_row10_col12, #T_f544c_row11_col0, #T_f544c_row11_col2, #T_f544c_row11_col4, #T_f544c_row11_col8, #T_f544c_row11_col9, #T_f544c_row11_col11, #T_f544c_row11_col12, #T_f544c_row12_col0, #T_f544c_row12_col2, #T_f544c_row12_col4, #T_f544c_row12_col8, #T_f544c_row12_col11, #T_f544c_row12_col12, #T_f544c_row13_col2, #T_f544c_row13_col8, #T_f544c_row13_col11, #T_f544c_row13_col12, #T_f544c_row14_col8, #T_f544c_row14_col11, #T_f544c_row15_col0, #T_f544c_row15_col2, #T_f544c_row15_col4, #T_f544c_row15_col8, #T_f544c_row15_col11, #T_f544c_row15_col12, #T_f544c_row16_col2, #T_f544c_row16_col8, #T_f544c_row16_col11, #T_f544c_row16_col12, #T_f544c_row17_col2, #T_f544c_row17_col8, #T_f544c_row17_col11, #T_f544c_row18_col0, #T_f544c_row18_col2, #T_f544c_row18_col4, #T_f544c_row18_col8, #T_f544c_row18_col11, #T_f544c_row18_col12, #T_f544c_row19_col2, #T_f544c_row19_col8, #T_f544c_row19_col11, #T_f544c_row19_col12, #T_f544c_row20_col2, #T_f544c_row20_col8, #T_f544c_row20_col11, #T_f544c_row21_col2, #T_f544c_row21_col4, #T_f544c_row21_col8, #T_f544c_row21_col11, #T_f544c_row21_col12, #T_f544c_row22_col4, #T_f544c_row22_col8, #T_f544c_row22_col11, #T_f544c_row22_col12, #T_f544c_row23_col8, #T_f544c_row23_col11, #T_f544c_row23_col12, #T_f544c_row24_col2, #T_f544c_row24_col7, #T_f544c_row24_col8, #T_f544c_row24_col9, #T_f544c_row24_col11, #T_f544c_row24_col12 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_f544c_row0_col1 {
#   background-color: #ffeded;
#   color: #000000;
# }
# #T_f544c_row0_col3 {
#   background-color: #ff9191;
#   color: #000000;
# }
# #T_f544c_row0_col5, #T_f544c_row15_col6 {
#   background-color: #fff9da;
#   color: #000000;
# }
# #T_f544c_row0_col6 {
#   background-color: #fff6c3;
#   color: #000000;
# }
# #T_f544c_row0_col7 {
#   background-color: #ababff;
#   color: #000000;
# }
# #T_f544c_row0_col9 {
#   background-color: #ffe8be;
#   color: #000000;
# }
# #T_f544c_row0_col10, #T_f544c_row1_col10, #T_f544c_row2_col10, #T_f544c_row4_col10, #T_f544c_row7_col10, #T_f544c_row8_col10, #T_f544c_row9_col10, #T_f544c_row10_col10, #T_f544c_row12_col10, #T_f544c_row13_col10, #T_f544c_row14_col10, #T_f544c_row15_col10, #T_f544c_row16_col10, #T_f544c_row17_col10, #T_f544c_row21_col10, #T_f544c_row22_col10 {
#   font-weight: bold;
#   background-color: #ffad17;
#   color: #000000;
# }
# #T_f544c_row1_col1 {
#   background-color: #ffcfcf;
#   color: #000000;
# }
# #T_f544c_row1_col3, #T_f544c_row12_col3 {
#   background-color: #ff7e7e;
#   color: #f1f1f1;
# }
# #T_f544c_row1_col5 {
#   background-color: #fffadd;
#   color: #000000;
# }
# #T_f544c_row1_col6 {
#   background-color: #fff4bb;
#   color: #000000;
# }
# #T_f544c_row1_col7 {
#   background-color: #ccccff;
#   color: #000000;
# }
# #T_f544c_row1_col9 {
#   background-color: #ffecc9;
#   color: #000000;
# }
# #T_f544c_row2_col0 {
#   background-color: #ffb8b8;
#   color: #000000;
# }
# #T_f544c_row2_col1, #T_f544c_row22_col1 {
#   background-color: #ff7272;
#   color: #f1f1f1;
# }
# #T_f544c_row2_col3, #T_f544c_row13_col3 {
#   background-color: #ff6767;
#   color: #f1f1f1;
# }
# #T_f544c_row2_col4, #T_f544c_row22_col6 {
#   background-color: #fff6c8;
#   color: #000000;
# }
# #T_f544c_row2_col5 {
#   background-color: #ffeb82;
#   color: #000000;
# }
# #T_f544c_row2_col6 {
#   background-color: #fff0a2;
#   color: #000000;
# }
# #T_f544c_row2_col7, #T_f544c_row14_col7 {
#   background-color: #c8c8ff;
#   color: #000000;
# }
# #T_f544c_row2_col9, #T_f544c_row3_col9 {
#   background-color: #ffe9c2;
#   color: #000000;
# }
# #T_f544c_row3_col0 {
#   background-color: #ff5959;
#   color: #f1f1f1;
# }
# #T_f544c_row3_col1, #T_f544c_row5_col1, #T_f544c_row6_col1, #T_f544c_row14_col1, #T_f544c_row23_col1, #T_f544c_row24_col1 {
#   font-weight: bold;
#   background-color: #ff1717;
#   color: #f1f1f1;
# }
# #T_f544c_row3_col2 {
#   background-color: #ffe8e8;
#   color: #000000;
# }
# #T_f544c_row3_col3 {
#   background-color: #ff5757;
#   color: #f1f1f1;
# }
# #T_f544c_row3_col4 {
#   background-color: #ffe86b;
#   color: #000000;
# }
# #T_f544c_row3_col5 {
#   background-color: #ffdd29;
#   color: #000000;
# }
# #T_f544c_row3_col6 {
#   background-color: #ffed8c;
#   color: #000000;
# }
# #T_f544c_row3_col7 {
#   background-color: #c9c9ff;
#   color: #000000;
# }
# #T_f544c_row3_col10, #T_f544c_row5_col10 {
#   background-color: #ffb01e;
#   color: #000000;
# }
# #T_f544c_row3_col12, #T_f544c_row14_col12 {
#   background-color: #f9d6f9;
#   color: #000000;
# }
# #T_f544c_row4_col0 {
#   background-color: #ffd0d0;
#   color: #000000;
# }
# #T_f544c_row4_col1 {
#   background-color: #ff7373;
#   color: #f1f1f1;
# }
# #T_f544c_row4_col3 {
#   background-color: #ff4c4c;
#   color: #f1f1f1;
# }
# #T_f544c_row4_col6 {
#   background-color: #fffce9;
#   color: #000000;
# }
# #T_f544c_row4_col7 {
#   background-color: #e5e5ff;
#   color: #000000;
# }
# #T_f544c_row4_col9 {
#   background-color: #fff6e5;
#   color: #000000;
# }
# #T_f544c_row5_col0 {
#   background-color: #ff6f6f;
#   color: #f1f1f1;
# }
# #T_f544c_row5_col3 {
#   background-color: #ff3c3c;
#   color: #f1f1f1;
# }
# #T_f544c_row5_col5 {
#   background-color: #fff3b3;
#   color: #000000;
# }
# #T_f544c_row5_col6 {
#   background-color: #fff8d2;
#   color: #000000;
# }
# #T_f544c_row5_col7, #T_f544c_row7_col7 {
#   background-color: #e3e3ff;
#   color: #000000;
# }
# #T_f544c_row5_col9 {
#   background-color: #fff5e3;
#   color: #000000;
# }
# #T_f544c_row6_col0 {
#   background-color: #ff6565;
#   color: #f1f1f1;
# }
# #T_f544c_row6_col3, #T_f544c_row8_col1, #T_f544c_row18_col3 {
#   background-color: #ff8282;
#   color: #f1f1f1;
# }
# #T_f544c_row6_col5 {
#   background-color: #fff3b5;
#   color: #000000;
# }
# #T_f544c_row6_col10 {
#   background-color: #ffd17c;
#   color: #000000;
# }
# #T_f544c_row7_col1, #T_f544c_row8_col0 {
#   background-color: #ffdcdc;
#   color: #000000;
# }
# #T_f544c_row7_col3 {
#   background-color: #ff8d8d;
#   color: #000000;
# }
# #T_f544c_row7_col6 {
#   background-color: #fffbe3;
#   color: #000000;
# }
# #T_f544c_row7_col9 {
#   background-color: #fff7e7;
#   color: #000000;
# }
# #T_f544c_row8_col3, #T_f544c_row13_col1 {
#   background-color: #ff7777;
#   color: #f1f1f1;
# }
# #T_f544c_row8_col5 {
#   background-color: #fff4b6;
#   color: #000000;
# }
# #T_f544c_row8_col6 {
#   background-color: #fff7ca;
#   color: #00
# <style type="text/css">
# #T_3e8ca .col2 {
#   border-left: 1px solid grey !important;
# }
# #T_3e8ca .col4 {
#   border-left: 1px solid grey !important;
# }
# #T_3e8ca .col6 {
#   border-left: 1px solid grey !important;
# }
# #T_3e8ca .col8 {
#   border-left: 1px solid grey !important;
# }
# #T_3e8ca .row2 {
#   border-top: 1px solid grey !important;
# }
# #T_3e8ca .row5 {
#   border-top: 1px solid grey !important;
# }
# #T_3e8ca .row7 {
#   border-top: 1px solid grey !important;
# }
# #T_3e8ca_row0_col0 {
#   background-color: #ffe5e5;
#   color: #000000;
# }
# #T_3e8ca_row0_col1 {
#   background-color: #ff9b9b;
#   color: #000000;
# }
# #T_3e8ca_row0_col2 {
#   background-color: #ffe661;
#   color: #000000;
# }
# #T_3e8ca_row0_col3, #T_3e8ca_row7_col3, #T_3e8ca_row8_col3, #T_3e8ca_row9_col3 {
#   font-weight: bold;
#   background-color: #ffdb17;
#   color: #000000;
# }
# #T_3e8ca_row0_col4, #T_3e8ca_row0_col5, #T_3e8ca_row0_col6, #T_3e8ca_row0_col7, #T_3e8ca_row0_col8, #T_3e8ca_row0_col9, #T_3e8ca_row1_col0, #T_3e8ca_row1_col1, #T_3e8ca_row1_col3, #T_3e8ca_row1_col4, #T_3e8ca_row1_col5, #T_3e8ca_row1_col6, #T_3e8ca_row1_col7, #T_3e8ca_row1_col8, #T_3e8ca_row1_col9, #T_3e8ca_row2_col1, #T_3e8ca_row2_col2, #T_3e8ca_row2_col3, #T_3e8ca_row2_col4, #T_3e8ca_row2_col5, #T_3e8ca_row2_col6, #T_3e8ca_row2_col7, #T_3e8ca_row2_col8, #T_3e8ca_row2_col9, #T_3e8ca_row3_col0, #T_3e8ca_row3_col1, #T_3e8ca_row3_col3, #T_3e8ca_row3_col4, #T_3e8ca_row3_col5, #T_3e8ca_row3_col6, #T_3e8ca_row3_col7, #T_3e8ca_row3_col8, #T_3e8ca_row3_col9, #T_3e8ca_row4_col0, #T_3e8ca_row4_col1, #T_3e8ca_row4_col2, #T_3e8ca_row4_col3, #T_3e8ca_row4_col4, #T_3e8ca_row4_col5, #T_3e8ca_row4_col6, #T_3e8ca_row4_col7, #T_3e8ca_row4_col9, #T_3e8ca_row5_col1, #T_3e8ca_row5_col3, #T_3e8ca_row5_col5, #T_3e8ca_row5_col7, #T_3e8ca_row5_col9, #T_3e8ca_row6_col0, #T_3e8ca_row6_col1, #T_3e8ca_row6_col2, #T_3e8ca_row6_col3, #T_3e8ca_row6_col4, #T_3e8ca_row6_col5, #T_3e8ca_row6_col7, #T_3e8ca_row6_col8, #T_3e8ca_row6_col9, #T_3e8ca_row7_col0, #T_3e8ca_row7_col4, #T_3e8ca_row7_col6, #T_3e8ca_row7_col8, #T_3e8ca_row8_col0, #T_3e8ca_row8_col4, #T_3e8ca_row8_col6, #T_3e8ca_row8_col8, #T_3e8ca_row9_col0, #T_3e8ca_row9_col4, #T_3e8ca_row9_col6, #T_3e8ca_row9_col8 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_3e8ca_row1_col2 {
#   font-weight: bold;
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_3e8ca_row2_col0 {
#   font-weight: bold;
#   background-color: #ff1717;
#   color: #f1f1f1;
# }
# #T_3e8ca_row3_col2 {
#   font-weight: bold;
#   background-color: #fff0a0;
#   color: #000000;
# }
# #T_3e8ca_row4_col8 {
#   font-weight: bold;
#   background-color: #fefafe;
#   color: #000000;
# }
# #T_3e8ca_row5_col0 {
#   background-color: #ff6c6c;
#   color: #f1f1f1;
# }
# #T_3e8ca_row5_col2 {
#   background-color: #ffee94;
#   color: #000000;
# }
# #T_3e8ca_row5_col4 {
#   font-weight: bold;
#   background-color: #1717ff;
#   color: #f1f1f1;
# }
# #T_3e8ca_row5_col6 {
#   background-color: #fffdf9;
#   color: #000000;
# }
# #T_3e8ca_row5_col8 {
#   background-color: #fffeff;
#   color: #000000;
# }
# #T_3e8ca_row6_col6 {
#   font-weight: bold;
#   background-color: #ffbf4b;
#   color: #000000;
# }
# #T_3e8ca_row7_col1 {
#   background-color: #ff7171;
#   color: #f1f1f1;
# }
# #T_3e8ca_row7_col2 {
#   background-color: #fffefa;
#   color: #000000;
# }
# #T_3e8ca_row7_col5 {
#   background-color: #bdbdff;
#   color: #000000;
# }
# #T_3e8ca_row7_col7 {
#   background-color: #ffbe48;
#   color: #000000;
# }
# #T_3e8ca_row7_col9 {
#   background-color: #fbe0fb;
#   color: #000000;
# }
# #T_3e8ca_row8_col1 {
#   background-color: #ff7474;
#   color: #f1f1f1;
# }
# #T_3e8ca_row8_col2 {
#   background-color: #fffbe5;
#   color: #000000;
# }
# #T_3e8ca_row8_col5 {
#   background-color: #c5c5ff;
#   color: #000000;
# }
# #T_3e8ca_row8_col7 {
#   background-color: #ffc55a;
#   color: #000000;
# }
# #T_3e8ca_row8_col9 {
#   background-color: #fbe3fb;
#   color: #000000;
# }
# #T_3e8ca_row9_col1 {
#   background-color: #ff7979;
#   color: #f1f1f1;
# }
# #T_3e8ca_row9_col2 {
#   background-color: #fff8d3;
#   color: #000000;
# }
# #T_3e8ca_row9_col5 {
#   background-color: #ceceff;
#   color: #000000;
# }
# #T_3e8ca_row9_col7 {
#   background-color: #ffcb6c;
#   color: #000000;
# }
# #T_3e8ca_row9_col9 {
#   background-color: #fce7fc;
#   color: #000000;
# }
# </style>
# <table id="T_3e8ca">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3e8ca_level0_col0" class="col_heading level0 col0" colspan="2">STR • 66 16 9 9 7</th>
#       <th id="T_3e8ca_level0_col2" class="col_heading level0 col2" colspan="2">DEX • 16 66 9 9 7</th>
#       <th id="T_3e8ca_level0_col4" class="col_heading level0 col4" colspan="2">INT • 21 20 50 9 7</th>
#       <th id="T_3e8ca_level0_col6" class="col_heading level0 col6" colspan="2">FTH • 21 20 9 50 7</th>
#       <th id="T_3e8ca_level0_col8" class="col_heading level0 col8" colspan="2">ARC • 24 19 7 8 50</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_3e8ca_level1_col0" class="col_heading level1 col0" >Standard</th>
#       <th id="T_3e8ca_level1_col1" class="col_heading level1 col1" >Std+Gse</th>
#       <th id="T_3e8ca_level1_col2" class="col_heading level1 col2" >Standard</th>
#       <th id="T_3e8ca_level1_col3" class="col_heading level1 col3" >Std+Gse</th>
#       <th id="T_3e8ca_level1_col4" class="col_heading level1 col4" >Standard</th>
#       <th id="T_3e8ca_level1_col5" class="col_heading level1 col5" >Std+Gse</th>
#       <th id="T_3e8ca_level1_col6" class="col_heading level1 col6" >Standard</th>
#       <th id="T_3e8ca_level1_col7" class="col_heading level1 col7" >Std+Gse</th>
#       <th id="T_3e8ca_level1_col8" class="col_heading level1 col8" >Standard</th>
#       <th id="T_3e8ca_level1_col9" class="col_heading level1 col9" >Std+Gse</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3e8ca_level0_row0" class="row_heading level0 row0" rowspan="2">Curved Greatswords</th>
#       <th id="T_3e8ca_level1_row0" class="row_heading level1 row0" >Bloodhound's Fang</th>
#       <th id="T_3e8ca_level2_row0" class="row_heading level2 row0" >No Prc</th>
#       <td id="T_3e8ca_row0_col0" class="data row0 col0" >334 (-17.7%)</td>
#       <td id="T_3e8ca_row0_col1" class="data row0 col1" >360 (-11.3%)</td>
#       <td id="T_3e8ca_row0_col2" class="data row0 col2" >380 (-6.4%)</td>
#       <td id="T_3e8ca_row0_col3" class="data row0 col3" >406 (👑)</td>
#       <td id="T_3e8ca_row0_col4" class="data row0 col4" >265 (-34.7%)</td>
#       <td id="T_3e8ca_row0_col5" class="data row0 col5" >291 (-28.3%)</td>
#       <td id="T_3e8ca_row0_col6" class="data row0 col6" >265 (-34.7%)</td>
#       <td id="T_3e8ca_row0_col7" class="data row0 col7" >291 (-28.3%)</td>
#       <td id="T_3e8ca_row0_col8" class="data row0 col8" >269 (-33.7%)</td>
#       <td id="T_3e8ca_row0_col9" class="data row0 col9" >295 (-27.3%)</td>
#     </tr>
#     <tr>
#       <th id="T_3e8ca_level1_row1" class="row_heading level1 row1" >Morgott's Cursed Sword</th>
#       <th id="T_3e8ca_level2_row1" class="row_heading level2 row1" >No Prc</th>
#       <td id="T_3e8ca_row1_col0" class="data row1 col0" >222 (-45.3%)</td>
#       <td id="T_3e8ca_row1_col1" class="data row1 col1" >- (-%)</td>
#       <td id="T_3e8ca_row1_col2" class="data row1 col2" >303 (-25.4%)</td>
#       <td id="T_3e8ca_row1_col3" class="data row1 col3" >- (-%)</td>
#       <td id="T_3e8ca_row1_col4" class="data row1 col4" >217 (-46.6%)</td>
#       <td id="T_3e8ca_row1_col5" class="data row1 col5" >- (-%)</td>
#       <td id="T_3e8ca_row1_col6" class="data row1 col6" >217 (-46.6%)</td>
#       <td id="T_3e8ca_row1_col7" class="data row1 col7" >- (-%)</td>
#       <td id="T_3e8ca_row1_col8" class="data row1 col8" >274 (-32.5%)</td>
#       <td id="T_3e8ca_row1_col9" class="data row1 col9" >- (-%)</td>
#     </tr>
#     <tr>
#       <th id="T_3e8ca_level0_row2" class="row_heading level0 row2" rowspan="3">Daggers</th>
#       <th id="T_3e8ca_level1_row2" class="row_heading level1 row2" >Cinquedea</th>
#       <th id="T_3e8ca_level2_row2" class="row_heading level2 row2" >No Prc</th>
#       <td id="T_3e8ca_row2

# %% [markdown]
# Usual weapons on the five main builds (one table)

# %%
weapons=["Dismounter","Bloodhound's Fang",
         "Banished Knight's Halberd",
         "2H Cleanrot Knight's Sword","Cleanrot Knight's Sword",
         "Wakizashi","Cinquedea","Scorpion's Stinger","Erdsteel Dagger",
         "Lance","Treespear",
         "Longsword","Carian Knight's Sword","Coded Sword",
         "Partisan","Spiked Spear",
         "2H Shamshir",
         "2H Godskin Stitcher"]
builds={"STR":[66,16,9,9,7],"DEX":[16,66,9,9,7],"INT":[21,20,50,9,7],"FTH":[21,20,9,50,7]}
infusions={"STR":["Heavy","Fire"],"DEX":["Keen","Lightning"],"INT":["Magic","Cold"],"FTH":["Sacred"]}
fancyTable(DMGtable(weapons,builds,infusions,weaponBuffs=True,counterHits=True),comparison="class",displayPercentage=True,showStats=True,multicolor=True,showWeaponClass=True)
# Out:
# <style type="text/css">
# #T_5569a .col6 {
#   border-left: 1px solid grey !important;
# }
# #T_5569a .col11 {
#   border-left: 1px solid grey !important;
# }
# #T_5569a .col15 {
#   border-left: 1px solid grey !important;
# }
# #T_5569a .row2 {
#   border-top: 1px solid grey !important;
# }
# #T_5569a .row5 {
#   border-top: 1px solid grey !important;
# }
# #T_5569a .row8 {
#   border-top: 1px solid grey !important;
# }
# #T_5569a .row11 {
#   border-top: 1px solid grey !important;
# }
# #T_5569a .row15 {
#   border-top: 1px solid grey !important;
# }
# #T_5569a .row21 {
#   border-top: 1px solid grey !important;
# }
# #T_5569a .row24 {
#   border-top: 1px solid grey !important;
# }
# #T_5569a .row30 {
#   border-top: 1px solid grey !important;
# }
# #T_5569a .row31 {
#   border-top: 1px solid grey !important;
# }
# #T_5569a_row0_col0, #T_5569a_row0_col2, #T_5569a_row0_col4, #T_5569a_row0_col5, #T_5569a_row0_col6, #T_5569a_row0_col9, #T_5569a_row0_col10, #T_5569a_row0_col12, #T_5569a_row0_col13, #T_5569a_row0_col14, #T_5569a_row0_col17, #T_5569a_row0_col18, #T_5569a_row1_col0, #T_5569a_row1_col1, #T_5569a_row1_col2, #T_5569a_row1_col3, #T_5569a_row1_col4, #T_5569a_row1_col6, #T_5569a_row1_col7, #T_5569a_row1_col8, #T_5569a_row1_col11, #T_5569a_row1_col12, #T_5569a_row1_col13, #T_5569a_row1_col14, #T_5569a_row1_col15, #T_5569a_row1_col16, #T_5569a_row1_col17, #T_5569a_row1_col18, #T_5569a_row2_col0, #T_5569a_row2_col2, #T_5569a_row2_col4, #T_5569a_row2_col5, #T_5569a_row2_col6, #T_5569a_row2_col9, #T_5569a_row2_col10, #T_5569a_row2_col12, #T_5569a_row2_col13, #T_5569a_row2_col14, #T_5569a_row2_col17, #T_5569a_row2_col18, #T_5569a_row3_col2, #T_5569a_row3_col4, #T_5569a_row3_col5, #T_5569a_row3_col9, #T_5569a_row3_col10, #T_5569a_row3_col12, #T_5569a_row3_col13, #T_5569a_row3_col14, #T_5569a_row3_col17, #T_5569a_row3_col18, #T_5569a_row4_col4, #T_5569a_row4_col5, #T_5569a_row4_col9, #T_5569a_row4_col10, #T_5569a_row4_col12, #T_5569a_row4_col13, #T_5569a_row4_col14, #T_5569a_row4_col17, #T_5569a_row4_col18, #T_5569a_row5_col2, #T_5569a_row5_col4, #T_5569a_row5_col5, #T_5569a_row5_col6, #T_5569a_row5_col7, #T_5569a_row5_col9, #T_5569a_row5_col10, #T_5569a_row5_col12, #T_5569a_row5_col13, #T_5569a_row5_col14, #T_5569a_row5_col17, #T_5569a_row5_col18, #T_5569a_row6_col2, #T_5569a_row6_col4, #T_5569a_row6_col5, #T_5569a_row6_col6, #T_5569a_row6_col9, #T_5569a_row6_col10, #T_5569a_row6_col12, #T_5569a_row6_col13, #T_5569a_row6_col14, #T_5569a_row6_col17, #T_5569a_row6_col18, #T_5569a_row7_col2, #T_5569a_row7_col4, #T_5569a_row7_col5, #T_5569a_row7_col6, #T_5569a_row7_col8, #T_5569a_row7_col9, #T_5569a_row7_col10, #T_5569a_row7_col11, #T_5569a_row7_col12, #T_5569a_row7_col13, #T_5569a_row7_col14, #T_5569a_row7_col15, #T_5569a_row7_col17, #T_5569a_row7_col18, #T_5569a_row8_col0, #T_5569a_row8_col2, #T_5569a_row8_col4, #T_5569a_row8_col5, #T_5569a_row8_col6, #T_5569a_row8_col7, #T_5569a_row8_col9, #T_5569a_row8_col10, #T_5569a_row8_col12, #T_5569a_row8_col13, #T_5569a_row8_col14, #T_5569a_row8_col17, #T_5569a_row8_col18, #T_5569a_row9_col2, #T_5569a_row9_col4, #T_5569a_row9_col5, #T_5569a_row9_col6, #T_5569a_row9_col9, #T_5569a_row9_col10, #T_5569a_row9_col12, #T_5569a_row9_col13, #T_5569a_row9_col14, #T_5569a_row9_col17, #T_5569a_row9_col18, #T_5569a_row10_col2, #T_5569a_row10_col4, #T_5569a_row10_col5, #T_5569a_row10_col9, #T_5569a_row10_col10, #T_5569a_row10_col12, #T_5569a_row10_col13, #T_5569a_row10_col14, #T_5569a_row10_col17, #T_5569a_row10_col18, #T_5569a_row11_col0, #T_5569a_row11_col1, #T_5569a_row11_col2, #T_5569a_row11_col3, #T_5569a_row11_col4, #T_5569a_row11_col5, #T_5569a_row11_col6, #T_5569a_row11_col7, #T_5569a_row11_col8, #T_5569a_row11_col9, #T_5569a_row11_col10, #T_5569a_row11_col11, #T_5569a_row11_col12, #T_5569a_row11_col13, #T_5569a_row11_col14, #T_5569a_row11_col15, #T_5569a_row11_col17, #T_5569a_row11_col18, #T_5569a_row12_col0, #T_5569a_row12_col2, #T_5569a_row12_col4, #T_5569a_row12_col5, #T_5569a_row12_col6, #T_5569a_row12_col9, #T_5569a_row12_col10, #T_5569a_row12_col12, #T_5569a_row12_col13, #T_5569a_row12_col14, #T_5569a_row12_col15, #T_5569a_row12_col17, #T_5569a_row12_col18, #T_5569a_row13_col0, #T_5569a_row13_col1, #T_5569a_row13_col2, #T_5569a_row13_col3, #T_5569a_row13_col5, #T_5569a_row13_col6, #T_5569a_row13_col7, #T_5569a_row13_col8, #T_5569a_row13_col9, #T_5569a_row13_col10, #T_5569a_row13_col11, #T_5569a_row13_col12, #T_5569a_row13_col13, #T_5569a_row13_col14, #T_5569a_row13_col15, #T_5569a_row13_col16, #T_5569a_row13_col17, #T_5569a_row13_col18, #T_5569a_row14_col0, #T_5569a_row14_col1, #T_5569a_row14_col2, #T_5569a_row14_col3, #T_5569a_row14_col4, #T_5569a_row14_col5, #T_5569a_row14_col6, #T_5569a_row14_col7, #T_5569a_row14_col8, #T_5569a_row14_col10, #T_5569a_row14_col11, #T_5569a_row14_col12, #T_5569a_row ...

# %% [markdown]
# Comparison between two builds, smaller format (no counterhit, percent values, weapon class display, color and weapon buffs)

# %%
weapons=["Dismounter","Banished Knight's Halberd","2H Cleanrot Knight's Sword","Cleanrot Knight's Sword","Wakizashi","Lance","Partisan","Spiked Spear","2H Shamshir","2H Godskin Stitcher","Carian Knight's Sword"]
builds={"STR/INT":[50,18,23,9,7],"INT/STR":[23,18,50,9,7]}
infusions={"STR/INT":["Heavy","Magic","Cold"],"INT/STR":["Magic","Cold"]}
fancyTable(DMGtable(weapons,builds,infusions,weaponBuffs=False,counterHits=False),comparison="class",displayPercentage=False,showStats=True,multicolor=False,showWeaponClass=False)
# Out:
# <style type="text/css">
# #T_47443 .col4 {
#   border-left: 1px solid grey !important;
# }
# #T_47443 .row1 {
#   border-top: 1px solid grey !important;
# }
# #T_47443 .row2 {
#   border-top: 1px solid grey !important;
# }
# #T_47443 .row3 {
#   border-top: 1px solid grey !important;
# }
# #T_47443 .row4 {
#   border-top: 1px solid grey !important;
# }
# #T_47443 .row5 {
#   border-top: 1px solid grey !important;
# }
# #T_47443 .row6 {
#   border-top: 1px solid grey !important;
# }
# #T_47443 .row8 {
#   border-top: 1px solid grey !important;
# }
# #T_47443 .row9 {
#   border-top: 1px solid grey !important;
# }
# #T_47443 .row10 {
#   border-top: 1px solid grey !important;
# }
# #T_47443_row0_col0, #T_47443_row0_col2, #T_47443_row0_col3, #T_47443_row0_col5, #T_47443_row0_col6, #T_47443_row1_col2, #T_47443_row1_col3, #T_47443_row1_col6, #T_47443_row2_col3, #T_47443_row2_col6, #T_47443_row3_col2, #T_47443_row3_col3, #T_47443_row3_col5, #T_47443_row3_col6, #T_47443_row4_col2, #T_47443_row4_col3, #T_47443_row4_col5, #T_47443_row4_col6, #T_47443_row5_col2, #T_47443_row5_col3, #T_47443_row5_col6, #T_47443_row6_col2, #T_47443_row6_col3, #T_47443_row6_col5, #T_47443_row6_col6, #T_47443_row7_col2, #T_47443_row7_col3, #T_47443_row7_col5, #T_47443_row7_col6, #T_47443_row8_col2, #T_47443_row8_col3, #T_47443_row8_col5, #T_47443_row8_col6, #T_47443_row9_col3, #T_47443_row9_col6, #T_47443_row10_col0, #T_47443_row10_col1, #T_47443_row10_col2, #T_47443_row10_col4, #T_47443_row10_col5 {
#   background-color: #f7fcf5;
#   color: #000000;
#   background-color: #f7fcf5;
#   color: #000000;
#   background-color: #f7fcf5;
#   color: #000000;
#   background-color: #f7fcf5;
#   color: #000000;
#   background-color: #f7fcf5;
#   color: #000000;
#   background-color: #f7fcf5;
#   color: #000000;
#   background-color: #f7fcf5;
#   color: #000000;
#   background-color: #f7fcf5;
#   color: #000000;
#   background-color: #f7fcf5;
#   color: #000000;
#   background-color: #f7fcf5;
#   color: #000000;
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_47443_row0_col1 {
#   background-color: #b6e2af;
#   color: #000000;
#   background-color: #b6e2af;
#   color: #000000;
#   background-color: #b6e2af;
#   color: #000000;
#   background-color: #b6e2af;
#   color: #000000;
#   background-color: #b6e2af;
#   color: #000000;
#   background-color: #b6e2af;
#   color: #000000;
#   background-color: #b6e2af;
#   color: #000000;
#   background-color: #b6e2af;
#   color: #000000;
#   background-color: #b6e2af;
#   color: #000000;
#   background-color: #b6e2af;
#   color: #000000;
#   background-color: #b6e2af;
#   color: #000000;
# }
# #T_47443_row0_col4, #T_47443_row1_col4, #T_47443_row2_col4, #T_47443_row3_col4, #T_47443_row4_col4, #T_47443_row5_col4, #T_47443_row6_col4, #T_47443_row8_col4, #T_47443_row9_col4, #T_47443_row10_col6 {
#   font-weight: bold;
#   background-color: #00441b;
#   color: #f1f1f1;
#   background-color: #00441b;
#   color: #f1f1f1;
#   background-color: #00441b;
#   color: #f1f1f1;
#   background-color: #00441b;
#   color: #f1f1f1;
#   background-color: #00441b;
#   color: #f1f1f1;
#   background-color: #00441b;
#   color: #f1f1f1;
#   background-color: #00441b;
#   color: #f1f1f1;
#   background-color: #00441b;
#   color: #f1f1f1;
#   background-color: #00441b;
#   color: #f1f1f1;
#   background-color: #00441b;
#   color: #f1f1f1;
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_47443_row1_col0 {
#   background-color: #ddf2d8;
#   color: #000000;
#   background-color: #ddf2d8;
#   color: #000000;
#   background-color: #ddf2d8;
#   color: #000000;
#   background-color: #ddf2d8;
#   color: #000000;
#   background-color: #ddf2d8;
#   color: #000000;
#   background-color: #ddf2d8;
#   color: #000000;
#   background-color: #ddf2d8;
#   color: #000000;
#   background-color: #ddf2d8;
#   color: #000000;
#   background-color: #ddf2d8;
#   color: #000000;
#   background-color: #ddf2d8;
#   color: #000000;
#   background-color: #ddf2d8;
#   color: #000000;
# }
# #T_47443_row1_col1 {
#   background-color: #cfecc9;
#   color: #000000;
#   background-color: #cfecc9;
#   color: #000000;
#   background-color: #cfecc9;
#   color: #000000;
#   background-color: #cfecc9;
#   color: #000000;
#   background-color: #cfecc9;
#   color: #000000;
#   background-color: #cfecc9;
#   color: #000000;
#   background-color: #cfecc9;
#   color: #000000;
#   background-color: #cfecc9;
#   color: #000000;
#   background-color: #cfecc9;
#   color: #000000;
#   background-color: #cfecc9;
#   color: #000000;
#   background-color: #cfecc9;
#   color: #000000;
# }
# #T_47443_row1_col5 {
#   background-color: #e8f6e4;
#   color: #000000;
#   background-color: #e8f6e4;
#   color: #000000;
#   background-color: #e8f6e4;
#   color: #000000;
#   background-color: #e8f6e4;
#   color: #000000;
#   background-color: #e8f6e4;
#   color: #000000;
#   background-color: #e8f6e4;
#   color: #000000;
#   background-color: #e8f6e4;
#   color: #000000;
#   background-color: #e8f6e4;
#   color: #000000;
#   background-color: #e8f6e4;
#   color: #000000;
#   background-color: #e8f6e4;
#   color: #000000;
#   background-color: #e8f6e4;
#   color: #000000;
# }
# #T_47443_row2_col0 {
#   background-color: #258d47;
#   color: #f1f1f1;
#   background-color: #258d47;
#   color: #f1f1f1;
#   background-color: #258d47;
#   color: #f1f1f1;
#   background-color: #258d47;
#   color: #f1f1f1;
#   background-color: #258d47;
#   color: #f1f1f1;
#   background-color: #258d47;
#   color: #f1f1f1;
#   background-color: #258d47;
#   color: #f1f1f1;
#   background-color: #258d47;
#   color: #f1f1f1;
#   background-color: #258d47;
#   color: #f1f1f1;
#   background-color: #258d47;
#   color: #f1f1f1;
#   background-color: #258d47;
#   color: #f1f1f1;
# }
# #T_47443_row2_col1 {
#   background-color: #bae3b3;
#   color: #000000;
#   background-color: #bae3b3;
#   color: #000000;
#   background-color: #bae3b3;
#   color: #000000;
#   background-color: #bae3b3;
#   color: #000000;
#   background-color: #bae3b3;
#   color: #000000;
#   background-color: #bae3b3;
#   color: #000000;
#   background-color: #bae3b3;
#   color: #000000;
#   background-color: #bae3b3;
#   color: #000000;
#   background-color: #bae3b3;
#   color: #000000;
#   background-color: #bae3b3;
#   color: #000000;
#   background-color: #bae3b3;
#   color: #000000;
# }
# #T_47443_row2_col2 {
#   background-color: #e4f5df;
#   color: #000000;
#   background-color: #e4f5df;
#   color: #000000;
#   background-color: #e4f5df;
#   color: #000000;
#   background-color: #e4f5df;
#   color: #000000;
#   background-color: #e4f5df;
#   color: #000000;
#   background-color: #e4f5df;
#   color: #000000;
#   background-color: #e4f5df;
#   color: #000000;
#   background-color: #e4f5df;
#   color: #000000;
#   background-color: #e4f5df;
#   color: #000000;
#   background-color: #e4f5df;
#   color: #000000;
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_47443_row2_col5 {
#   background-color: #f5fbf2;
#   color: #000000;
#   background-color: #f5fbf2;
#   color: #000000;
#   background-color: #f5fbf2;
#   color: #000000;
#   background-color: #f5fbf2;
#   color: #000000;
#   background-color: #f5fbf2;
#   color: #000000;
#   background-color: #f5fbf2;
#   color: #000000;
#   background-color: #f5fbf2;
#   color: #000000;
#   background-color: #f5fbf2;
#   color: #000000;
#   background-color: #f5fbf2;
#   color: #000000;
#   background-color: #f5fbf2;
#   color: #000000;
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_47443_row3_col0 {
#   background-color: #e6f5e1;
#   color: #000000;
#   background-color: #e6f5e1;
#   color: #000000;
#   background-color: #e6f5e1;
#   color: #000000;
#   background-color: #e6f5e1;
#   color: #000000;
#   background-color: #e6f5e1;
#   color: #000000;
#   background-color: #e6f5e1;
#   color: #000000;
#   background-color: #e6f5e1;
#   color: #000000;
#   background-color: #e6f5e1;
#   color: #000000;
#   background-color: #e6f5e1;
#   color: #000000;
#   background-color: #e6f5e1;
#   color: #000000;
#   background-color: #e6f5e1;
#   color: #000000;
# }
# #T_47443_row3_col1 {
#   background-color: #bce4b5;
#   color: #000000;
#   background-color: #bce4b5;
#   color: #000000;
#   background-color: #bce4b5;
#   color: #000000;
#   background-color: #bce4b5;
#   color: #000000;
#   background-color: #bce4b5;
#   color: #000000;
#   background-color: #bce4b5;
#   color: #000000;
#   background-color: #bce4b5;
#   color: #000000;
#   background-color: #bce4b5;
#   color: #000000;
#   background-color: #bce4b5;
#   color: #000000;
#   b

# %% [markdown]
# Weapon class comparison

# %%
weapons=weaponsOfClass("HTS")
builds={"STR":[66,16,9,9,7],"DEX":[16,66,9,9,7],"INT":[21,20,50,9,7],"FTH":[21,20,9,50,7],"ARC":[24,19,7,8,50]}
infusions={"STR":["Heavy","Fire"],"DEX":["Keen","Lightning"],"INT":["Magic","Cold"],"FTH":["Sacred"],"ARC":["Occult","Blood"]}
fancyTable(DMGtable(weapons,builds,infusions,weaponBuffs=True,counterHits=True),comparison="class",displayPercentage=True,showStats=True,multicolor=True,showWeaponClass=False)
# Out:
# <style type="text/css">
# #T_bc6c0 .col5 {
#   border-left: 1px solid grey !important;
# }
# #T_bc6c0 .col9 {
#   border-left: 1px solid grey !important;
# }
# #T_bc6c0 .col12 {
#   border-left: 1px solid grey !important;
# }
# #T_bc6c0 .col15 {
#   border-left: 1px solid grey !important;
# }
# #T_bc6c0_row0_col0, #T_bc6c0_row0_col2, #T_bc6c0_row0_col4, #T_bc6c0_row0_col5, #T_bc6c0_row0_col8, #T_bc6c0_row0_col10, #T_bc6c0_row0_col11, #T_bc6c0_row0_col14, #T_bc6c0_row0_col15, #T_bc6c0_row0_col16, #T_bc6c0_row0_col17, #T_bc6c0_row1_col2, #T_bc6c0_row1_col4, #T_bc6c0_row1_col8, #T_bc6c0_row1_col10, #T_bc6c0_row1_col11, #T_bc6c0_row1_col14, #T_bc6c0_row1_col15, #T_bc6c0_row1_col16, #T_bc6c0_row1_col17, #T_bc6c0_row2_col4, #T_bc6c0_row2_col8, #T_bc6c0_row2_col10, #T_bc6c0_row2_col11, #T_bc6c0_row2_col14, #T_bc6c0_row2_col15, #T_bc6c0_row2_col17, #T_bc6c0_row3_col0, #T_bc6c0_row3_col2, #T_bc6c0_row3_col4, #T_bc6c0_row3_col5, #T_bc6c0_row3_col8, #T_bc6c0_row3_col10, #T_bc6c0_row3_col11, #T_bc6c0_row3_col14, #T_bc6c0_row3_col15, #T_bc6c0_row3_col16, #T_bc6c0_row3_col17, #T_bc6c0_row4_col2, #T_bc6c0_row4_col4, #T_bc6c0_row4_col8, #T_bc6c0_row4_col10, #T_bc6c0_row4_col11, #T_bc6c0_row4_col14, #T_bc6c0_row4_col15, #T_bc6c0_row4_col16, #T_bc6c0_row4_col17, #T_bc6c0_row5_col2, #T_bc6c0_row5_col4, #T_bc6c0_row5_col8, #T_bc6c0_row5_col10, #T_bc6c0_row5_col11, #T_bc6c0_row5_col14, #T_bc6c0_row5_col15, #T_bc6c0_row5_col17, #T_bc6c0_row6_col0, #T_bc6c0_row6_col1, #T_bc6c0_row6_col2, #T_bc6c0_row6_col3, #T_bc6c0_row6_col4, #T_bc6c0_row6_col5, #T_bc6c0_row6_col6, #T_bc6c0_row6_col7, #T_bc6c0_row6_col9, #T_bc6c0_row6_col10, #T_bc6c0_row6_col11, #T_bc6c0_row6_col12, #T_bc6c0_row6_col13, #T_bc6c0_row6_col14, #T_bc6c0_row6_col15, #T_bc6c0_row6_col16, #T_bc6c0_row6_col17, #T_bc6c0_row7_col0, #T_bc6c0_row7_col1, #T_bc6c0_row7_col2, #T_bc6c0_row7_col3, #T_bc6c0_row7_col4, #T_bc6c0_row7_col5, #T_bc6c0_row7_col6, #T_bc6c0_row7_col7, #T_bc6c0_row7_col9, #T_bc6c0_row7_col10, #T_bc6c0_row7_col11, #T_bc6c0_row7_col12, #T_bc6c0_row7_col13, #T_bc6c0_row7_col14, #T_bc6c0_row7_col15, #T_bc6c0_row7_col16, #T_bc6c0_row7_col17, #T_bc6c0_row8_col0, #T_bc6c0_row8_col1, #T_bc6c0_row8_col2, #T_bc6c0_row8_col3, #T_bc6c0_row8_col4, #T_bc6c0_row8_col5, #T_bc6c0_row8_col6, #T_bc6c0_row8_col7, #T_bc6c0_row8_col9, #T_bc6c0_row8_col10, #T_bc6c0_row8_col11, #T_bc6c0_row8_col12, #T_bc6c0_row8_col13, #T_bc6c0_row8_col14, #T_bc6c0_row8_col15, #T_bc6c0_row8_col16, #T_bc6c0_row8_col17, #T_bc6c0_row9_col0, #T_bc6c0_row9_col1, #T_bc6c0_row9_col2, #T_bc6c0_row9_col3, #T_bc6c0_row9_col4, #T_bc6c0_row9_col5, #T_bc6c0_row9_col6, #T_bc6c0_row9_col7, #T_bc6c0_row9_col8, #T_bc6c0_row9_col9, #T_bc6c0_row9_col10, #T_bc6c0_row9_col11, #T_bc6c0_row9_col12, #T_bc6c0_row9_col13, #T_bc6c0_row9_col14, #T_bc6c0_row9_col15, #T_bc6c0_row9_col16, #T_bc6c0_row10_col0, #T_bc6c0_row10_col1, #T_bc6c0_row10_col2, #T_bc6c0_row10_col3, #T_bc6c0_row10_col4, #T_bc6c0_row10_col5, #T_bc6c0_row10_col6, #T_bc6c0_row10_col7, #T_bc6c0_row10_col8, #T_bc6c0_row10_col9, #T_bc6c0_row10_col10, #T_bc6c0_row10_col11, #T_bc6c0_row10_col12, #T_bc6c0_row10_col13, #T_bc6c0_row10_col14, #T_bc6c0_row10_col15, #T_bc6c0_row10_col16, #T_bc6c0_row11_col0, #T_bc6c0_row11_col1, #T_bc6c0_row11_col2, #T_bc6c0_row11_col3, #T_bc6c0_row11_col4, #T_bc6c0_row11_col5, #T_bc6c0_row11_col6, #T_bc6c0_row11_col7, #T_bc6c0_row11_col8, #T_bc6c0_row11_col9, #T_bc6c0_row11_col10, #T_bc6c0_row11_col11, #T_bc6c0_row11_col12, #T_bc6c0_row11_col13, #T_bc6c0_row11_col14, #T_bc6c0_row11_col15, #T_bc6c0_row11_col16 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_bc6c0_row0_col1 {
#   background-color: #ffe1e1;
#   color: #000000;
# }
# #T_bc6c0_row0_col3 {
#   background-color: #ff8282;
#   color: #f1f1f1;
# }
# #T_bc6c0_row0_col6 {
#   background-color: #fff8d0;
#   color: #000000;
# }
# #T_bc6c0_row0_col7 {
#   background-color: #fff7ca;
#   color: #000000;
# }
# #T_bc6c0_row0_col9 {
#   background-color: #cdcdff;
#   color: #000000;
# }
# #T_bc6c0_row0_col12 {
#   background-color: #ffedcd;
#   color: #000000;
# }
# #T_bc6c0_row0_col13, #T_bc6c0_row1_col13 {
#   font-weight: bold;
#   background-color: #ffad17;
#   color: #000000;
# }
# #T_bc6c0_row1_col0 {
#   background-color: #ffcece;
#   color: #000000;
# }
# #T_bc6c0_row1_col1 {
#   background-color: #ff8686;
#   color: #f1f1f1;
# }
# #T_bc6c0_row1_col3 {
#   background-color: #ff6d6d;
#   color: #f1f1f1;
# }
# #T_bc6c0_row1_col5 {
#   background-color: #fff4ba;
#   color: #000000;
# }
# #T_bc6c0_row1_col6 {
#   background-color: #ffe972;
#   color: #000000;
# }
# #T_bc6c0_row1_col7 {
#   background-color: #fff2af;
#   color: #000000;
# }
# #T_bc6c0_row1_col9 {
#   background-color: #c5c5ff;
#   color: #000000;
# }
# #T_bc6c0_row1_col12 {
#   background-color: #ffebc5;
#   color: #000000;
# }
# #T_bc6c0_row2_col0 {
#   background-color: #ff7070;
#   color: #f1f1f1;
# }
# #T_bc6c0_row2_col1 {
#   background-color: #ff2c2c;
#   color: #f1f1f1;
# }
# #T_bc6c0_row2_col2 {
#   background-color: #fff7f7;
#   color: #000000;
# }
# #T_bc6c0_row2_col3 {
#   background-color: #ff5b5b;
#   color: #f1f1f1;
# }
# #T_bc6c0_row2_col5 {
#   background-color: #ffe55b;
#   color: #000000;
# }
# #T_bc6c0_row2_col6 {
#   font-weight: bold;
#   background-color: #ffdb17;
#   color: #000000;
# }
# #T_bc6c0_row2_col7 {
#   background-color: #ffef98;
#   color: #000000;
# }
# #T_bc6c0_row2_col9 {
#   background-color: #c2c2ff;
#   color: #000000;
# }
# #T_bc6c0_row2_col12 {
#   background-color: #ffe9c2;
#   color: #000000;
# }
# #T_bc6c0_row2_col13 {
#   background-color: #ffaf1c;
#   color: #000000;
# }
# #T_bc6c0_row2_col16 {
#   background-color: #fbe0fb;
#   color: #000000;
# }
# #T_bc6c0_row3_col1 {
#   background-color: #ffdbdb;
#   color: #000000;
# }
# #T_bc6c0_row3_col3 {
#   background-color: #ff9393;
#   color: #000000;
# }
# #T_bc6c0_row3_col6 {
#   background-color: #fffcec;
#   color: #000000;
# }
# #T_bc6c0_row3_col7, #T_bc6c0_row4_col5 {
#   background-color: #fff9db;
#   color: #000000;
# }
# #T_bc6c0_row3_col9 {
#   background-color: #e1e1ff;
#   color: #000000;
# }
# #T_bc6c0_row3_col12 {
#   background-color: #fff4e1;
#   color: #000000;
# }
# #T_bc6c0_row3_col13 {
#   font-weight: bold;
#   background-color: #ffb42b;
#   color: #000000;
# }
# #T_bc6c0_row4_col0 {
#   background-color: #ffc8c8;
#   color: #000000;
# }
# #T_bc6c0_row4_col1, #T_bc6c0_row4_col3 {
#   background-color: #ff8080;
#   color: #f1f1f1;
# }
# #T_bc6c0_row4_col6 {
#   background-color: #ffee93;
#   color: #000000;
# }
# #T_bc6c0_row4_col7 {
#   background-color: #fff6c3;
#   color: #000000;
# }
# #T_bc6c0_row4_col9 {
#   background-color: #dbdbff;
#   color: #000000;
# }
# #T_bc6c0_row4_col12 {
#   background-color: #fff2db;
#   color: #000000;
# }
# #T_bc6c0_row4_col13 {
#   font-weight: bold;
#   background-color: #ffb52d;
#   color: #000000;
# }
# #T_bc6c0_row5_col0 {
#   background-color: #ff6b6b;
#   color: #f1f1f1;
# }
# #T_bc6c0_row5_col1 {
#   font-weight: bold;
#   background-color: #ff2727;
#   color: #f1f1f1;
# }
# #T_bc6c0_row5_col3 {
#   background-color: #ff6e6e;
#   color: #f1f1f1;
# }
# #T_bc6c0_row5_col5 {
#   background-color: #ffeb80;
#   color: #000000;
# }
# #T_bc6c0_row5_col6 {
#   background-color: #ffe03c;
#   color: #000000;
# }
# #T_bc6c0_row5_col7 {
#   background-color: #fff2ad;
#   color: #000000;
# }
# #T_bc6c0_row5_col9 {
#   background-color: #d7d7ff;
#   color: #000000;
# }
# #T_bc6c0_row5_col12 {
#   background-color: #fff2da;
#   color: #000000;
# }
# #T_bc6c0_row5_col13 {
#   background-color: #ffb734;
#   color: #000000;
# }
# #T_bc6c0_row5_col16 {
#   background-color: #fbe5fb;
#   color: #000000;
# }
# #T_bc6c0_row6_col8 {
#   font-weight: bold;
#   background-color: #fff4b8;
#   color: #000000;
# }
# #T_bc6c0_row7_col8 {
#   font-weight: bold;
#   background-color: #ffed8b;
#   color: #000000;
# }
# #T_bc6c0_row8_col8 {
#   font-weight: bold;
#   background-color: #ffe65e;
#   color: #000000;
# }
# #T_bc6c0_row9_col17, #T_bc6c0_row10_col17 {
#   font-weight: bold;
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_bc6c0_row11_col17 {
#   font-weight: bold;
#   background-color: #fadbfa;
#   color: #000000;
# }
# </style>
# <table id="T_bc6c0">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bc6c0_level0_col0" class="col_heading level0 col0" colspan="5">STR • 66 16 9 9 7</th>
#       <th id="T_bc6c0_level0_col5" c

# %%
#TODO vérifier que FS et SB sont applicables (ex fist)
#TODO tri par dégats/portée
#TODO choix type atk (rr1, cl1 etc)
